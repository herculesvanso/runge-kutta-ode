# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from rungekutta import *

# %%
def f(t,X):
    return np.array(
        [-20*X[0]+10*X[1]+100, 10*X[0]-20*X[1]]
    )

# %%
a = 0.
b = 5.
X0 = np.array([0.,0.])
f = f

# %%
tab1 = RK(a,b,X0,m=1000,f=f)
tab1
# Out:
#           t         x    d/dt x
# 0     0.000  0.000000  0.000000
# 1     0.005  0.476005  0.011701
# 2     0.010  0.907781  0.043845
# 3     0.015  1.300411  0.092509
# 4     0.020  1.658324  0.154368
# ...     ...       ...       ...
# 996   4.980  6.666667  3.333333
# 997   4.985  6.666667  3.333333
# 998   4.990  6.666667  3.333333
# 999   4.995  6.666667  3.333333
# 1000  5.000  6.666667  3.333333
#
# [1001 rows x 3 columns]

# %%
tab2 = RK(a,b,X0,m=10,f=f)
tab2
# Out:
#       t             x        d/dt x
# 0   0.0  0.000000e+00  0.000000e+00
# 1   0.5 -2.804167e+03  2.677083e+03
# 2   1.0 -4.513031e+06  4.511162e+06
# 3   1.5 -7.424106e+09  7.424081e+09
# 4   2.0 -1.221542e+13  1.221542e+13
# 5   2.5 -2.009894e+16  2.009894e+16
# 6   3.0 -3.307030e+19  3.307030e+19
# 7   3.5 -5.441304e+22  5.441304e+22
# 8   4.0 -8.952986e+25  8.952986e+25
# 9   4.5 -1.473102e+29  1.473102e+29
# 10  5.0 -2.423805e+32  2.423805e+32

# %%
tab3 = RK(a,b=100,X0=X0,m=10**5,f=f)
tab3
# Out:
#               t         x    d/dt x
# 0         0.000  0.000000  0.000000
# 1         0.001  0.099008  0.000493
# 2         0.002  0.196066  0.001948
# 3         0.003  0.291220  0.004324
# 4         0.004  0.384519  0.007587
# ...         ...       ...       ...
# 99996    99.996  6.666667  3.333333
# 99997    99.997  6.666667  3.333333
# 99998    99.998  6.666667  3.333333
# 99999    99.999  6.666667  3.333333
# 100000  100.000  6.666667  3.333333
#
# [100001 rows x 3 columns]

# %%
plt.plot(tab1.iloc[:,0],tab1.iloc[:,1],tab1.iloc[:,0],tab1.iloc[:,2])
plt.xlabel('Time (s)')
plt.ylabel('Current Intensity(A)')
plt.grid(True)
plt.show()

# %%
plt.semilogy(tab2.iloc[:,0],np.abs(tab2.iloc[:,1]),tab2.iloc[:,0], np.abs (tab2.iloc[:,2]), 'ro')
plt.xlabel('Time (s) ')
plt.ylabel('Current Intensity(A)')
plt.grid(True)
plt.show()

# %%
plt.plot(tab3.iloc[:,0],tab3.iloc[:,1],tab3.iloc[:,0],tab3.iloc[:,2])
plt.xlabel('Time (s)')
plt.ylabel('Current Intensity(A)')
plt.grid(True)
plt.show()
